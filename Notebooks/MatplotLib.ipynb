# %%
import matplotlib.pyplot as plt
from random import *
from math import *
import numpy as np

# %%
x = [random.randint(1, 1000) for i in range(200)]

# %%
y = [random.randint(1, 1000) for i in range(200)]

# %%
colors = [random.randint(1, 100) for i in range(200)]

# %%
plt.scatter([random.randint(1, 1000) for i in range(200)], [random.randint(1, 1000) for i in range(200)], c=[random.randint(1, 100) for i in range(200)])

# %%
plt.plot([random.randint(1, 1000) for i in range(200)], [random.randint(1, 1000) for i in range(200)], color="red", linestyle="dashed", marker="o", markerfacecolor="blue", markersize=10)

# %%
x = [i for i in range(10)]

# %%
y = [sin(i) for i in x]

# %%
plt.plot(x, y, color="red", marker="o", markerfacecolor="blue")

# %%
# Bar Plot

# %%
left = [randint(1, 200) for i in range(100)]

# %%
height = [randint(1, 500) for i in range(100)]

# %%
plt.bar(left, height, width=7, color=["red", "green", "blue"])
# Out:
# <BarContainer object of 100 artists>

# %%
colors = ["r", "y", "g", "b", "r", "y", "b"]

# %%
items = ["Apple", "Banana", "Grapes", "Pear", "Guava", "Mango", "Kiwi"]

# %%
slices = [randint(1, 10) for i in range(7)]

# %%
plt.pie(slices, labels=items, colors=colors, startangle=90, shadow=True, explode=(0, 0.2, 0.5, 0, 1, 0, 0), radius=1.2)
# Out:
# ([<matplotlib.patches.Wedge at 0x24266f32588>,
# ...
#  [Text(-0.6745446607567187, 1.1346318789125411, 'Apple'),
#   Text(-1.5188845945989546, 0.05822017081707546, 'Banana'),
#   Text(-1.0470799972916747, -1.4886314114889778, 'Grapes'),
#   Text(0.585710165724381, -1.1829385452199612, 'Pear'),
#   Text(2.183444893852467, -0.7841992065219074, 'Guava'),
#   Text(1.3112907644459761, 0.15138206987185615, 'Mango'),
#   Text(0.7594207079192269, 1.0796667024519466, 'Kiwi')])

# %%
x = np.arange(0, 2*(np.pi), 0.1)

# %%
y = np.cos(x)

# %%
plt.plot(x, y)
