# %%
# Regression Basics
# Using Data Sets from Quandl

# %%
import pandas as pd
import quandl as qd
import math

# %%
qd.ApiConfig.api_key = '75WpiEyyBvn2gYbn3yiS'

# %%
df = qd.get_table('SHARADAR/SF1', paginate=True)

# %%
df.head(10)
# Out:
#      ticker dimension calendardate    datekey reportperiod lastupdated  \
# None
# 0         A       MRY   2011-12-31 2011-10-31   2011-10-31  2018-08-30
# 1         A       MRY   2012-12-31 2012-10-31   2012-10-31  2018-08-30
# 2         A       MRY   2013-12-31 2013-10-31   2013-10-31  2018-08-30
# 3         A       MRY   2014-12-31 2014-10-31   2014-10-31  2018-08-30
# 4         A       MRY   2015-12-31 2015-10-31   2015-10-31  2018-08-30
# 5         A       MRY   2016-12-31 2016-10-31   2016-10-31  2018-08-30
# 6         A       MRY   2017-12-31 2017-10-31   2017-10-31  2018-08-30
# 7        AA       MRY   2013-12-31 2013-12-31   2013-12-31  2018-08-02
# 8        AA       MRY   2014-12-31 2014-12-31   2014-12-31  2018-08-02
# 9        AA       MRY   2015-12-31 2015-12-31   2015-12-31  2018-08-02
#
#             accoci        assets     assetsavg       assetsc       ...        \
# None                                                               ...
# ...

# %%
df.columns
# Out:
# Index(['ticker', 'dimension', 'calendardate', 'datekey', 'reportperiod',
#        'lastupdated', 'accoci', 'assets', 'assetsavg', 'assetsc',
#        ...
#        'sharesbas', 'shareswa', 'shareswadil', 'sps', 'tangibles', 'taxassets',
#        'taxexp', 'taxliabilities', 'tbvps', 'workingcapital'],
#       dtype='object', length=111)

# %%
df.dtypes
# Out:
# ticker                    object
# dimension                 object
# calendardate      datetime64[ns]
# datekey           datetime64[ns]
# reportperiod      datetime64[ns]
# lastupdated       datetime64[ns]
# accoci                   float64
# assets                   float64
# assetsavg                float64
# assetsc                  float64
# assetsnc                 float64
# assetturnover            float64
# bvps                     float64
# capex                    float64
# cashneq                  float64
# cashnequsd               float64
# cor                      float64
# consolinc                float64
# currentratio             float64
# de                       float64
# debt                     float64
# debtc                    float64
# debtnc                   float64
# debtusd                  float64
# deferredrev              float64
# depamor                  float64
# deposits                 float64
# divyield                 float64
# ...

# %%
df = df[["assets", "price", "revenue", "workingcapital"]]

# %%
df.head()
# Out:
#             assets  price       revenue  sharefactor  workingcapital
# None
# 0     9.057000e+09  37.07  6.615000e+09          1.0    3.732000e+09
# 1     1.053600e+10  35.99  6.858000e+09          1.0    2.736000e+09
# 2     1.068600e+10  50.76  3.894000e+09          1.0    3.381000e+09
# 3     1.081500e+10  55.28  4.048000e+09          1.0    3.817000e+09
# 4     7.479000e+09  37.76  4.038000e+09          1.0    2.710000e+09

# %%
forecast_col = "revenue"
df.fillna(0, inplace=True)

# %%
forecast_out = int(math.ceil(0.1*len(df)))

# %%
df["Forecast_Revenue"] = df[forecast_col].shift(-forecast_out)
# df.dropna(inplace=True)

# %%
df.head()
# Out:
#             assets  price       revenue  sharefactor  workingcapital  \
# None
# 0     9.057000e+09  37.07  6.615000e+09          1.0    3.732000e+09
# 1     1.053600e+10  35.99  6.858000e+09          1.0    2.736000e+09
# 2     1.068600e+10  50.76  3.894000e+09          1.0    3.381000e+09
# 3     1.081500e+10  55.28  4.048000e+09          1.0    3.817000e+09
# 4     7.479000e+09  37.76  4.038000e+09          1.0    2.710000e+09
#
#       Forecast_Revenue
# None
# 0         1.210389e+10
# 1         1.221576e+10
# 2         1.234930e+10
# 3         7.684778e+06
# 4         8.055958e+06
